# %% [markdown]
# # Import yFinance

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\python38\lib\site-packages (0.1.55)
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas>=0.24 in c:\python38\lib\site-packages (from yfinance) (1.2.0)
# Requirement already satisfied: numpy>=1.15 in c:\python38\lib\site-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in c:\python38\lib\site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python38\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in c:\python38\lib\site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python38\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\python38\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\python38\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\python38\lib\site-packages (from requests>=2.20->yfinance) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\python38\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python38\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: six>=1.5 in c:\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.14.0)

# %% [markdown]
# # Import Libraries

# %%
import IPython
import numpy as np
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from datetime import datetime
from IPython.display import display
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pd.set_option('display.max_rows', 5000)
import plotly.express as px

# %% [markdown]
# ### Fetching list of companies

# %%
company_list = pd.DataFrame(pd.read_excel("NSEcomp.xlsx")) 
company_list['Company Name'] = company_list['Company Name'].str.cat(company_list['Symbol'],sep="-")

# %%
def calculate_adjusted_prices(df, column):
    adj_column = 'adj_' + column
    df.sort_index(ascending=False, inplace=True)

    price_col = df[column].values
    split_col = df['Splits'].values
    dividend_col = df['Dividends'].values
    adj_price_col = np.zeros(len(df.index))
    adj_price_col[0] = price_col[0]

    for i in range(1, len(price_col)):
        adj_price_col[i] = round((adj_price_col[i - 1] + adj_price_col[i - 1] *
                   (((price_col[i]) -
                     price_col[i - 1] -
                     dividend_col[i - 1]) / price_col[i - 1])), 6)

    df[adj_column] = adj_price_col
    df.sort_index(ascending=True, inplace=True)

    return df

# %%
def fetch_data():
    global df
    df = pd.DataFrame(yf.download(Company.value[Company.value.index('-')+1:] + '.NS', period=Duration.value, interval=Interval.value))
    df = df.dropna()
    msft = yf.Ticker(Company.value[Company.value.index('-')+1:] + '.NS')
    global dr
    dr = pd.DataFrame(msft.dividends)
    global dp
    dp = pd.DataFrame(msft.splits)
    df["Dividends"]=dr["Dividends"]
    df = df.fillna(0)
    df["Splits"]=dp["Stock Splits"]
    df = df.fillna(1)
    df=df.reset_index()
    calculate_adjusted_prices(df, 'Open')
    calculate_adjusted_prices(df, 'High')
    calculate_adjusted_prices(df, 'Low')
    calculate_adjusted_prices(df, 'Close')

# %%
companies = company_list["Company Name"].tolist()
Interval = widgets.SelectionSlider(
    options=['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo'],
    value='1d',
    description='Interval',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True
)

Company = widgets.Combobox(
    placeholder='Company',
    options=companies,
    description='Company:',
    ensure_option=True,
    disabled=False
)
 
Duration = widgets.Text(
    value='1y',
    placeholder='Type something',
    continuous_update=False,
    description='Duration:',
    disabled=False
)

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        IPython.display.clear_output(wait=False)
        display(Company)
        display(Duration)
        display(Interval)
        fetch_data()
        print(df.head(10))
        maxi = df['High'].max()
        mini = df['High'].min()
        fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['adj_Open'],
                high=df['adj_High'],
                low=df['adj_Low'],
                close=df['adj_Close'])])
        fig.update_layout( title='Historical Data of Stock Prices', 
                          yaxis_title=Company.value+" Stock Price ------->",
                          xaxis_title=" Time ------->",)
        fig.layout.plot_bgcolor = '#d1d1cd'
        fig.layout.paper_bgcolor = '#d1d1cd'
        for dt in df[df['Dividends']>0]['Date'].tolist():
            yi = df[df['Date']==dt]['adj_High'].tolist()[0]
            temp = 0
            if yi > (maxi+mini)/2:
                temp = -(maxi-mini)/50
            else:
                temp = (maxi-mini)/50
            fig.add_annotation(x=dt, 
                       y=yi,
                       xref="x",
                       yref="y",
                       text="D",
                       showarrow=True,
                       bgcolor="#ff7f0e", 
#                        arrowside = "end+start",
                       hovertext = str(dt)[0:10] + " Dividend = " + str(sum(df[df['Date'] == dt]['Dividends'].tolist())),
                       opacity=0.8)

        for dt1 in df[df['Splits']!=1.0]['Date'].tolist():
            yi = df[df['Date']==dt1]['adj_High'].tolist()[0]
            temp = 0
            if yi > (maxi+mini)/2:
                temp = -(maxi-mini)/50
            else:
                temp = (maxi-mini)/50
            fig.add_annotation(x=dt, 
                       y=yi + 10,
                       xref="x",
                       yref="y",
                       text="S",
                       showarrow=True,
                       hovertext = str(dt)[0:10] + " Stock Split = " + str(sum(df[df['Date'] == dt1]['Splits'].tolist())),
                       bgcolor="#ff7f0e",
                       opacity=0.8)
        fig.show()


Company.observe(on_change)
Duration.observe(on_change)
Interval.observe(on_change)
display(Company)
display(Duration)
display(Interval)
# Out:
# Combobox(value='ITC Limited-ITC', description='Company:', ensure_option=True, options=('Reliance Industries Li…
# Text(value='1y', continuous_update=False, description='Duration:', placeholder='Type something')
# SelectionSlider(continuous_update=False, description='Interval', index=8, options=('1m', '2m', '5m', '15m', '3…
# [*********************100%***********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-03-05  187.550003  191.199997  186.550003  188.050003  174.712540
# 1 2020-03-06  184.850006  184.850006  179.750000  181.750000  168.859375
# 2 2020-03-09  179.000000  179.000000  174.500000  177.199997  164.632080
# 3 2020-03-11  174.000000  176.750000  172.350006  175.649994  163.192001
# 4 2020-03-12  169.000000  169.149994  150.550003  155.800003  144.749878
# 5 2020-03-13  150.000000  164.000000  134.600006  162.250000  150.742401
# 6 2020-03-16  158.000000  158.100006  145.250000  147.250000  136.806290
# 7 2020-03-17  148.000000  155.800003  146.050003  149.149994  138.571518
# 8 2020-03-18  152.100006  154.649994  147.350006  150.699997  140.011597
# 9 2020-03-19  150.699997  163.550003  144.750000  161.850006  150.370789
#
#      Volume  Dividends  Splits    adj_Open    adj_High     adj_Low   adj_Close
# 0  20025924        0.0     1.0  174.322117  177.737489  173.214454  174.712545
# 1  26764504        0.0     1.0  171.812551  171.834605  166.900550  168.859370
# 2  21794299        0.0     1.0  166.375145  166.396501  162.025847  164.632076
# 3  27956087        0.0     1.0  161.727795  164.304925  160.029546  163.192007
# 4  52039692        0.0     1.0  157.080445  157.240040  139.787919  144.749878
# 5  61590681        0.0     1.0  139.420513  152.452660  124.978109  150.742409
# 6  33254907        0.0     1.0  146.856274  146.968088  134.866787  136.806285
# 7  47657482        0.0     1.0  137.561573  144.830030  135.609602  138.571522
# 8  50243331        0.0     1.0  141.372406  143.760994  136.816674  140.011591
# 9  89748454        0.0     1.0  140.071139  152.034348  134.402530  150.370785
# <div>                            <div id="3bbf99ee-0de4-428a-8361-8fdcbca62bfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("